# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.arange(5)
y = np.array([2, 3, 1, 7, 4])

plt.plot(x, y)
plt.xticks([0, 1, 2, 3, 4], ['a', 'b', 'c', 'd', 'e'])
plt.xlabel('xlabel')
plt.show()
