# %% [markdown]
# # 对话聚类

# %% [markdown]
# ## 1. 数据清洗
# - 将每段对话合并为一行
# - 正则表达式替换特定字符串
# - 分词
# - 删除停用词（包括长度为1的词）

# %%
import re
import jieba
import logging
import time

raw_file = 'chat-short-20w.txt'
stop_wrods_file = 'stop_words.txt'

jieba.setLogLevel(logging.INFO)
logging.basicConfig(format='%(message)s', level=logging.DEBUG)

def substitute(sent):
    exps = [
        r'#E-\w\[数字x\]|~O\(∩_∩\)O/~',
        r'http[s]?://[a-zA-Z0-9|\.|/]+',
        r'http[s]?://[a-zA-Z0-9\./-]*\[链接x\]',
        r'\[ORDERID_[0-9]+\]',
        r'\[日期x\]',
        r'\[时间x\]',
        r'\[金额x\]',
        r'\[站点x\]',
        r'\[数字x\]',
        r'\[地址x\]',
        r'\[姓名x\]',
        r'\[邮箱x\]',
        r'\[电话x\]',
        r'\[商品快照\]',
        r'<s>',
        r'\s+',
        r'[a-z|0-9]+'
        "[\s+\.\!\/_,$%^:*(+\"\')]+",
        "[+——()?:【】‘’“”`！，。？、~@#￥%……&*（）]+"
    ]
    for exp in exps:
        sent = re.sub(exp, ' ', sent)
    return sent

logging.info('数据清洗开始...')

# 读取原始数据文件
with open(raw_file, encoding='utf-8') as f:
    data = f.read().strip().split('\n\n')  # '\n\n'分隔每段对话
    
# 将每段对话合并为一行
corpus = []
for conv_raw in data:
    conv = conv_raw.strip().split('\n')  # '\n'分隔每句话
    conv = list(map(lambda x: x.strip()[2:], conv))  # 去除开头的0/1标记
    corpus.append(' '.join(conv))    
logging.info('Step1: 合并完成 (共%d段对话)' % len(corpus))


# 正则表达式替换特定字符串
corpus = list(map(substitute, corpus))
logging.info('Setp2: 正则表达式替换完成')

# 分词
t = time.time()
corpus = list(map(jieba.cut, corpus))
logging.info('Step3: 分词完成')

# 删除停用词
logging.info('Step4: 删除停用词开始...')
with open(stop_wrods_file, encoding='utf-8') as f:
    stop_words = f.read().strip().split('\n')
    
t = time.time()
for i in range(len(corpus)):
    tokens = []
    for token in corpus[i]:
        token = token.strip()
        if len(token) > 1 and token not in stop_words:
            tokens.append(token)
    corpus[i] = tokens
logging.info('Step4: 删除停用词完成 (用时: %.2fs)' % (time.time() - t))

# 组合
corpus = list(map(lambda x: ' '.join(x), corpus))

logging.info('数据清洗完成.')
# Out:
# 数据清洗开始...
# Step1: 合并完成 (共10942段对话)
# Setp2: 正则表达式替换完成
# Step3: 分词完成
# Step4: 删除停用词开始...
# Step4: 删除停用词完成 (用时: 21.08s)
# 数据清洗完成.

# %% [markdown]
# ## 2. 转化为TFIDF标签

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# 关键超参数
max_df=0.1
min_df = 20
max_features=1000

tfidf_vectorizer = TfidfVectorizer(max_df=max_df, min_df=min_df, max_features=max_features)
tfidf = tfidf_vectorizer.fit_transform(corpus)
logging.info('tfifd标签转化完成')
# Out:
# tfifd标签转化完成

# %%
import matplotlib.pyplot as plt

print('words:', len(tfidf_vectorizer.vocabulary_), end='\n\n')
print()

terms = tfidf_vectorizer.get_feature_names()
conv_idx = 0
for row in tfidf[:2]:
    conv_idx += 1
    print('Conv %d: ' % conv_idx, end='')
    row = row.toarray().squeeze()
    num = min(20, (row != 0).sum())
    row_sub = row.argsort()[:-1-num:-1]
    words = [terms[idx] for idx in row_sub]
    print(' '.join(words), end='\n\n')
# Out:
# words: 1000
#
# Conv 1: 先发 有货 到货 操作 我家 啥时候 一周 快点 希望 关注 库房 多久 左右 两个 物流 稍等一下 建议您
#
# Conv 2: 耽误 及时 着急 拦截 签收 下发 我点 过程 能查 第一次 灰常 这次 这种 估计 算了 积极 这么久 为止 直到 包裹

# %% [markdown]
# ## 3. Cluster
# - Use kmeans

# %%
from sklearn.cluster import KMeans

# %%
n_clusters=50
max_iter=100

# %%
kmeans = KMeans(n_clusters=n_clusters,
                    max_iter=max_iter,
                    n_init=8,
                    init='k-means++',
                    n_jobs=-1,
                    random_state=0,
                    verbose=2)
labels = kmeans.fit_predict(tfidf)
# Out:
# Initialization complete
# Initialization complete
# Initialization complete
# Initialization complete
# Initialization complete
# Initialization complete
# Initialization complete
# Initialization complete
# Iteration  0, inertia 10561.943
# Iteration  0, inertia 15622.129
# Iteration  0, inertia 15525.568
# Iteration  0, inertia 10546.624
# Iteration  0, inertia 10628.762
# Iteration  0, inertia 15603.777
# Iteration  0, inertia 15458.489
# Iteration  0, inertia 10600.951
# Iteration  1, inertia 9196.286
# Iteration  1, inertia 9683.404
# Iteration  1, inertia 9582.199
# Iteration  1, inertia 9540.153
# Iteration  1, inertia 9238.047
# Iteration  1, inertia 9166.440
# Iteration  1, inertia 9674.196
# Iteration  1, inertia 9174.358
# Iteration  2, inertia 9062.136
# Iteration  2, inertia 9292.410
# Iteration  2, inertia 9285.002
# Iteration  2, inertia 9003.151
# Iteration  2, inertia 9293.386
# Iteration  2, inertia 9177.764
# Iteration  2, inertia 9018.696
# Iteration  2, inertia 8969.824
# Iteration  3, inertia 9150.783
# Iteration  3, inertia 9169.254
# Iteration  3, inertia 8975.162
# Iteration  3, inertia 9068.336
# Iteration  3, inertia 8934.301
# Iteration  3, inertia 8890.278
# Iteration  3, inertia 9124.611
# Iteration  3, inertia 8957.263
# Iteration  4, inertia 9100.292
# Iteration  4, inertia 8858.973
# Iteration  4, inertia 9129.224
# Iteration  4, inertia 8914.343
# Iteration  4, inertia 9069.560
# Iteration  4, inertia 8901.996
# Iteration  4, inertia 9029.787
# Iteration  4, inertia 8914.475
# Iteration  5, inertia 9076.075
# Iteration  5, inertia 8846.725
# Iteration  5, inertia 8884.835
# Iteration  5, inertia 9057.035
# Iteration  5, inertia 8881.617
# Iteration  5, inertia 9110.889
# Iteration  5, inertia 9010.891
# Iteration  5, inertia 8887.621
# Iteration  6, inertia 8834.775
# Iteration  6, inertia 9055.009
# Iteration  6, inertia 8869.297
# Iteration  6, inertia 8869.166
# Iteration  6, inertia 9050.435
# Iteration  6, inertia 8998.658
# Iteration  6, inertia 9096.994
# Iteration  7, inertia 8821.979
# Iteration  7, inertia 8859.161
# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
clusters = [[] for _ in range(n_clusters)]
for i in range(len(corpus)):
    clusters[labels[i]].append(corpus[i])

# %%
for k in range(n_clusters):
    vectorizer = CountVectorizer()
    count = vectorizer.fit_transform(clusters[k])
    words = vectorizer.get_feature_names()
    counts = count.toarray().sum(0)
    index = counts.argsort()[-1:-1-15:-1]

    print('total', len(clusters[k]), end=': ')
    for i in index:
        print(words[i], end=' ')
    print('\n')
# Out:
# total 222: 取消 拦截 订单 退款 成功 处理 请问 申请 问题 谢谢 拒收 配送 已经 帮到 下单
#
# total 68: 需要 联系 电脑 谢谢 请问 处理 问题 亲爱 一直 客气 客户 为您服务 乐意 帮到 订单
#
# total 321: 取件 问题 处理 上门 请问 退货 申请 售后 需要 谢谢 解决 帮到 地址 一下 商品
#
# total 40: 售后 申请 gt 处理 问题 订单 打开 京东 确认 退换货 返修 商品 收货 手机 维修
#
# total 58: 工作日 退款 取消 时效 问题 一下 微信 处理 订单 支付 两个 零钱 信用卡 储蓄卡 客户
#
# total 303: 修改 订单 地址 请问 问题 处理 取消 下单 解决 时间 一下 您好 配送 谢谢 帮到
#
# total 251: 请问 再见 问题 京东 支持 订单 帮到 祝您 生活 感谢您 愉快 谢谢 处理 解决 取消
#
# total 133: 申请 价保 订单 问题 请问 处理 成功 谢谢 需要 商品 订单号 解决 帮到 降价 支付
#
# total 233: 安装 请问 问题 订单 处理 需要 服务 电话 预约 解决 一下 谢谢 帮到 售后 厂家
#
# total 97: 退款 亲爱 处理 返还 订单 回复 之后 需要 问题 拒收 取消 一直 完成 咨询 申请
#
# total 245: 问题 客服 处理 请问 订单 谢谢 申请 解决 一下 需要 余额 退款 帮到 麻烦 提供
#
# total 239: 发票 请问 订单 处理 问题 开具 一下 谢谢 商品 解决 需要 您好 帮到 查询 已经
#
# total 230: 物流 问题 处理 请问 订单 配送 信息 解决 更新 谢谢 帮到 京东 时间 发货 今天
#
# total 258: 拒收 退款 处理 订单 问题 请问 取消 商品 申请 已经 谢谢 帮到 解决 退货 需要
#
# total 151: 师傅 处理 配送 联系 问题 电话 请问 站点 订单 解决 地址 帮到 谢谢 一下 快递
#
# total 178: 发票 电子 订单 开具 问题 请问 处理 查询 谢谢 完成 帮到 解决 需要 您好 下载
#
# total 132: 发货 请问 调货 仓库 商品 需要 问题 时间 显示 订单 下单 您好 解决 一下 处理
#
# total 185: 手机 问题 请问 处理 谢谢 一下 解决 订单 联系 帮到 配送 申请 电话 畅通 保持
#
# total 209: 问题 到货 请问 处理 客户 遇到 订单 帮到 商品 解决 小妹 时间 谢谢 预计 支持
#
# total 175: 运费 问题 请问 处理 订单 谢谢 需要 商品 解决 会员 退货 申请 您好 plus 帮到
#
# total 260: 送到 处理 配送 问题 订单 请问 今天 解决 站点 明天 谢谢 帮到 时间 一下 预计
#
# total 209: 收货 问题 处理 订单 确认 请问 解决 申请 谢谢 地址 收到 一下 帮到 需要 联系
#
# total 176: 支付 订单 请问 问题 处理 谢谢 退款 取消 解决 申请 商品 下单 需要 一下 帮到
#
# total 166: 抱歉 站点 订单 签收 核实 配送 处理 问题 谢谢 一下 妹子 请问 通知 实在 跟进
#
# total 117: 派送 订单 处理 问题 请问 配送 快递 站点 解决 谢谢 已经 联系 今天 帮到 时间
#
# total 125: 下午 配送 处理 问题 请问 明天 联系 订单 时间 站点 谢谢 解决 一下 上午 帮到
#
# total 107: 白条 退款 请问 还款 订单 问题 处理 支付 已经 谢谢 申请 银行卡 帮到 解决 取消
#
# total 160: 订单 缺货 发货 商品 时间 预计 请问 处理 问题 谢谢 解决 显示 送达 下单 帮到
#
# total 246: 看看 请问 问题 处理 订单 小妹 解决 谢谢 帮到 商品 时间 一下 申请 下单 联系
#
# total 110: 商家 订单 申请 取消 处理 退款 请问 问题 谢谢 一下 等待 联系 商品 帮到 解决
#
# total 108: 售后 申请 返修 联系 问题 审核 之后 之前 处理 提交 退换货 退货 订单 请问 人员
#
# total 232: 申请 售后 客户服务 退换 问题 直接 处理 京东 退换货 点击 app 返修 请问 链接 路径
#
# total 166: 维修 问题 售后 申请 处理 请问 商品 京东 需要 质保 解决 查询 一下 您好 谢谢
#
# total 304: 回复 处理 需要 问题 咨询 联系 我会 消息 多个 一对一 订单 解决 配送 请问 帮到
#
# total 167: 差价 申请 订单 处理 请问 问题 降价 谢谢 取消 帮到 成功 下单 支付 解决 已经
#
# total 135: 请问 问题 谢谢 商品 处理 满意 再次 您好 客气 期待 为您服务 追求 帮到 解决 查询
#
# total 228: 换货 问题 申请 处理 请问 退货 解决 售后 商品 需要 谢谢 帮到 一下 订单 已经
#
# total 186: 到达 订单 问题 请问 处理 站点 配送 今天 谢谢 帮到 解决 预计 时间 一下 已经
#
# total 242: 订单 预计 送达 手中 处理 问题 请问 时间 解决 谢谢 发货 帮到 下单 配送 明天
#
# total 180: 问题 请问 处理 方便 描述 简单 解决 商品 查询 订单 您好 帮到 谢谢 配送 联系
#
# total 231: 配送 订单 京东 准备 问题 处理 请问 解决 电话 送往 完成 发货 今天 谢谢 正在
#
# total 132: 订单 价格 申请 谢谢 请问 需要 保护 差价 一下 订单号 问题 处理 商品 帮到 取消
#
# total 188: 预约 联系 电话 请问 提前 一下 转告 送货 时间 麻烦 送到 在家 妹子 手机 担心
#
# total 217: 工作日 退款 订单 请问 储蓄卡 处理 信用卡 申请 支付 取消 京东 问题 银行 周期 微信
#
# total 70: 回复 订单 服务 客服 亲爱 在线 抱歉 耐心 实在 回应 辛苦 小手指 达到 过来 有时候
#
# total 73: 北京 处理 问题 订单 请问 地址 解决 配送 发货 谢谢 今天 送达 帮到 商品 预计
#
# total 39: 妹子 注意 客户 辛苦 评价 遇到 一个 请问 身体 支持 问题 帮到 为您服务 谢谢 高兴
#
# total 101: 发票 修改 抬头 税号 问题 处理 请问 谢谢 电子 公司 订单 需要 一下 提供 解决
#
# total 189: 审核 处理 申请 问题 请问 退款 订单 需要 帮到 取消 谢谢 解决 已经 退货 等待
#
# total 2350: 问题 处理 请问 订单 解决 谢谢 帮到 配送 商品 一下 取消 时间 下单 联系 您好

# %% [markdown]
# ## 5. Conversations

# %%
with open('chat-short-20w.txt', encoding='utf8') as f:
    cons = f.read().strip().split('\n\n')

# %%
clusters = [[] for _ in range(n_clusters)]
for i in range(len(cons)):
    clusters[labels[i]].append(cons[i])

# %%
topic_idx = 5

for conv in clusters[topic_idx][:15]:
    print(conv, end='\n\n')
# Out:
# 0 你好我地址写错了能改吗? 那个地址是我家但是已经回老家了没人收货
# 1 有什么问题我可以帮您处理或解决呢? 您好 还辛苦您再等待下哦，这里正在为您查询中哈! [商品快照] 请问是这个商品吗
# 0 好的 是
# 1 哦哦 您好，正常情况下订单提交成功是不支持修改的呢，麻烦您看下订单详情页是否有“修改”的按钮，如有，您可点击修改末级地址/联系人/电话号码/送货时间信息，如没有修改按钮，说明订单已不支持修改了呢，还请您理解哦~#E-s[数字x]#E-s[数字x]
# 0 那个地址没有人收货了啊 下单时间:[日期x] 那如果我申请退货呢
# 1 可以的 需要我给您取消下的吗
# 0 得多长时间能退回款? 申请取消订单后我再下单改地址 是你们帮我申请快还是我自己申请快啊? 我已经自己申请退款了
# 1 财务审核通过，退款中 已经在操作了 最快今天可以退款完成原路返回的
# 0 ok 谢谢您了
# 1 正常周期是[数字x]-[数字x]天左右的 辛苦了 不客气的，您的满意是我们的追求。期待能再次为您服务，#E-s[数字x] 请问还有其他还可以帮到您的吗?
# 0 没有了谢谢
# 1 “满意度评价”为我加油，也好让我们能再续良缘哦~谢谢您哦#E-s[数字x] 感谢您对京东的支持，祝您生活愉快，再见!
# 0 对了，我要在哪里查看退款进度啊?
# 1 点击售后哪里 有这个订单是进度的 我可以在退款完成后短信通知下您的
# 0 没找到啊
# 1 您是手机 还是电脑
# 0 手机 我再次购买发现地址没错啊，怎么就发到廊坊去了呢
#
# 0 你好
# 1 有什么问题我可以帮您处理或解决呢?
# 0 我地址错了 你帮我改一下地址 潍坊[地址x]
# 1 您好，正常情况下订单提交成功是不支持修改的呢，麻烦您看下订单详情页是否有“修改”的按钮，如有，您可点击修改末级地址/联系人/电话号码/送货时间信息，如没有修改按钮，说明订单已不支持修改了呢，还请您理解哦~#E-s[数字x]#E-s[数字x]
# 0 我想取消订单
# 1 我代为申请下可以吗
# 0 直接取消吧
# 1 [ORDERID_10006574] 稍等 申请了
# 0 退款就行了
# 1 嗯
# 0 麻烦了
#
# 0 [时间x]] 你好
# 1 您好，请问有什么可以帮您?#E-s[数字x]
# 0 你好，我这个订单想修改下地址
# 1 亲不好意思哈
# 0 能不能麻烦你直接改?还是我取消订单重新拍?
# 1 这边不能修改的 麻烦您重新拍一下
# 0 哦，好吧
# 1 #E-s[数字x]#E-s[数字x]
# 0 谢谢
#
# 0 [时间x]] 售后另约时间
# 1 有什么问题我可以帮您处理或解决呢?
# 0 我要另约时间 要怎么操作
# 1 修改取件时间吗
# 0 对
# 1 什么时间呢
# 0 今天或明天
# 1 明天早上[数字x]-[数字x]可以吗
# 0 [数字x]点后
# 1 已经修改 这个只能大概时效的
# 0 好的
# 1 #E-s[数字x] 辛苦您等待下哦 请问还有其他还可以帮到您的吗?
# 0 你们取完货什么时候能拿到新的
# 1 咱们售后接收到商品，确定有质量问题时[数字x]日之内会给您完成换货的哦~到时您的京东账户内会有换新订单哒，还麻烦您查看呢~
# 0 但是[数字x]号之后我没空，你们你能尽快处理吗
# 1 这边收货之后很快处理的
# 0 好的 谢谢
#
# 1 有什么问题我可以帮您处理或解决呢?
# 0 能改地址吗
# 1 马上核实情况，请您稍等哈#E-s[数字x] 无法使用取消订单重新下单呢
# 0 广东[地址x] 不能
# 1 那就退款重新购买呢 #E-s[数字x]
# 0 #E-s[数字x] 你不能改吗?
# 1 我这边无法修改订单信息呢
# 0 #E-s[数字x] 好吧
# 1 请问还有其他还可以帮到您的吗?
# 0 谢谢
#
# 0 我想把这笔订单的发票改一下可以吗 [时间x]]
# 1 您好 有什么问题我可以帮您处理或解决呢? 还请您稍等，马上为您查询~ 京东E[姓名x]JOY狗年贺岁卡[数字x]面值(实体卡) 请问是这个商品吗
# 0 对 [数字x]张[数字x]元面值京东E卡 [时间x]]
# 1 发票已经开具 公司抬头的 没法修改抬头了 您需要改什么的呢
# 0 我想改成增值税专用发票
# 1 哦哦，资质通过了吗 如果通过了 可以修改的
# 0 纸质版的
# 1 您看呢
# 0 我从哪申请修改发票
# 1 不用您申请 您先看下您的资质通过没 通过后我来给您反馈修改
# 0 啥资质i，我没懂
# 1 稍等下 有效 这些 已经通过了 您要是修改，我给您反馈修改下 可以吗 只有这个修改对吗
# 0 就是可以修改适马
# 1 是的 可以修改的 周期是[数字x]-[数字x]个工作日修改后给您邮寄过去的呢 您注意查收哈 辛苦了呢
# 0 好的，那我修改成增值税专用发票 纸质的
# 1 开票内容是明细的哦 对的亲，纸质的增值税专用发票的呢 您看嗯
# 0 嗯嗯，可以
# 1 好的呢 就安排了哈 已经反馈了呢
# 0 [姓名x]
# 1 辛苦了哈 请问还有其他还可以帮到您的吗? 不客气的，您的满意是我们的追求。期待能再次为您服务，#E-s[数字x]
# 0 没有了，谢谢
#
# 0 https://item.jd.com/3561321.html 售后服务单号:[数字x] 收货地址能改么
# 1 您好，请问有什么可以帮助您的么#E-s[数字x]
# 0 默认是我浦东的 我想改一下
# 1 显示审核了呢 这个是无法直接修改地址了哦 这边给您备注一下看看呢
# 0 上海[地址x] 不对 我看错了，没事了 取件地址不用管。。。
# 1 收货地址看到是已经修改了呢
# 0 嗯 我看凑了 看错了
# 1 这个您等待售后处理的哦
# 0 没事了，谢谢
#
# 0 想改地址 改 地址
# 1 请您稍等一下，正在为您核实处理中哦~ 有没有修改的按钮哦
# 0 有但是现实不支持修改#E-s[数字x]
# 1 可以考虑下重新下单的
# 0 那算了吧!你们送过来，我再发顺丰吧!
# 1 好的 那按您的地址正常配送去
# 0 好
# 1 请问还有其他还可以帮到您的吗?
#
# 0 我想問一下東西已經發貨的情況下可以更改收貨人手機號碼嗎 因為可能要換手機號
# 1 您好 有什么问题我可以帮您处理或解决呢? 还请您稍等，马上为您查询~ 请问是这个商品吗 镜头
# 0 是的 但是現在還沒換手機號呢 就這兩天換，我怕他發貨了就不能更改收貨人信息了
# 1 您的订单预计[数字x]月[数字x]日送达您手中 您好，正常情况下订单提交成功是不支持修改的呢，麻烦您看下订单详情页是否有“修改”的按钮，如有，您可点击修改末级地址/联系人/电话号码/送货时间信息，如没有修改按钮，说明订单已不支持修改了呢，还请您理解哦~#E-s[数字x]#E-s[数字x]
# 0 好吧 那我到時候可以联系送货员给他电话号码吧
# 1 好的呢， 辛苦您了 请问还有其他还可以帮到您的吗?
# 0 沒有了，謝謝
#
# 0 下单时间:[日期x]
# 1 请问有什么可以帮您?
# 0 我这个赠品订单修改地址会影响主品吗
# 1 都是会修改的呢 是拆分的订单呢
# 0 拆分的订单啊
# 1 是的呢
# 0 那这个修改的话，那个也会一起修改吗
# 1 应该是的哈，因为这个原先是一个订单的呢
# 0 这个上面说是要等那个确认收货才会给这个发货的
# 1 是的呢
# 0 那也会影响啊
# 1 是的哈
# 0 好吧
# 1 不好意思呢
# 0 没事的
# 1 请问还有其他还可以帮到您的吗?
# 0 没有了
#
# 0 这个单子我想改派送地址 下单时间:[日期x]
# 1 有什么问题我可以帮您处理或解决呢? 您是要修改地址吗
# 0 是的修改配送地址
# 1 订单生成之后地址不能修改了吗
# 0 是的
# 1 您前台不能修改的话我们这边也是不能修改呢
# 0 好吧。
# 1 确实非常抱歉呢
# 0 没事，到时候我给派送员打电话吧
# 1 好的 请问还有其他还可以帮到您的吗?
# 0 没了 谢谢
#
# 0 你好 下单时间:[日期x]
# 1 有什么问题我可以帮您处理或解决呢?
# 0 这个你现在没货，不知道什么时间发，我想改地址
# 1 辛苦您点击我的订单，找到您的订单，点击订单后面的订单详细，进入之后右上角您查看下是否有修改按钮，要是没有的话，是不支持修改的哦，还请您见谅
# 0 那你这个什么时间能发货
# 1 预计是[数字x]-[数字x]个工作日左右的 预计是今明两天会到货发出的
# 0 那到福建要多久 我是看到你们信息写的[数字x]号能到才买的 超过这个时间就不在这了
# 1 您这个取消重新下单
# 0 离开时发出也没用啊
# 1 您取消订单
# 0 好的
#
# 1 请问有什么可以帮您?
# 0 帮我修改一个订单的地址。 下单时间:[日期x]
# 1 需要修改多远的呢
# 0 地址改为广东[地址x]
# 1 距离大约有几公里呢
# 0 [数字x]公里内
# 1 妹子转告一下站点哈 您稍等
# 0 为什么不可以直接修改了? 以前都可以的。 我点的太快了。
# 1 应该是因为超过时间了呢
# 0 不会吧，我点完之后我看到就直接修改了。
# 1 您是刚下的订单吗
# 0 你帮我后台操作一下啦，因为那个地址的话，我怕没收到。 是啊，我下订单不久啊，应该是两分钟之内。
# 1 也是可以取消重新下比较快，如果您这边不想取消妹子就帮您转告站点呢
# 0 你帮我转告吧。 我这边用白条的也不好操作。
# 1 好的呢
# 0 谢谢
# 1 现在还没有站点的呢 先帮您备注一下哈 您先保持手机畅通的呢
# 0 好
#
# 1 有什么问题我可以帮您处理或解决呢?#E-s[数字x]#E-s[数字x]#E-s[数字x]
# 0 爱您好客服人员我买的药品我查看了一下物流你们发到湖北[地址x] 谢谢啊，第一次遇到这样的问题
# 1 很抱歉呢
# 0 请问能帮我在配送途中解决问题吗把我的发货地址把收货地址请修改到苏州让物流那边给我们修改过来把货发到苏州来好吗我已经等了很多天了谢谢
# 1 是无法修改地址的哦
# 0 可是客服人员我现在人在苏州我在京东这个个人设置中地址已经修改过是不是你们没有看到发货地址按照我以前的电话号码看到我以前的地址发货的呢 如果不能修改的话那这个货已经发到黄石了我看了一下物流已经到黄石了嗯那我现在该怎么处理呢 还有就是如果说这个发货地址不能修改的话那我以后是不是就不能在京东大药房买东西啦如果下次再买东西是不是还要发到老地址去呢
# 1 如无法代为签收 建议您拒收下 给您退货处理
# 0 退货处理后你们是不是重新发货给我
# 1 无法直接发货 需要您重新下单
# 0 嗯你好客服人员嗯如果说取消订单的话我现在在哪儿操作你告诉我在哪个窗口操作 还有送货地址我明明修改清楚的你们为什么会发到老地址呢我觉得很奇怪如果我再重新订货你们是不是还会发到老地址去
# 1 及时直接申请退款 就是取消订单的哦 或是妹子给联系站点 帮您直接拦截
# 0 您好客服人员麻烦你帮我直接拦截然后能不能那么只有我自己重新下订单的事吗谢谢啊请现在就帮我拦截掉
# 1 好滴 拦截成功后 给您退回后 退款的呢 可能需要一些时间
# 0 好的谢谢客服人员请尽快把拦截工作做完然后我重新下单本来我就很需要这些药在等着用呢
#
# 0 下单时间:[日期x]
# 1 您好 有什么问题我可以帮您处理或解决呢? [商品快照]
# 0 请问可以修改
# 1 请问是这个商品吗
# 0 收货地址么 嗯啊 修改收货地址
# 1 您好，正常情况下订单提交成功是不支持修改的呢，麻烦您看下订单详情页是否有“修改”的按钮，如有，您可点击修改末级地址/联系人/电话号码/送货时间信息，如没有修改按钮，说明订单已不支持修改了呢，还请您理解哦~#E-s[数字x]#E-s[数字x] 您这个已经发了 没法改了呢 报气呢 抱歉呢
# 0 好吧谢谢
# 1 不客气的，您的满意是我们的追求。期待能再次为您服务，#E-s[数字x] 请问还有其他还可以帮到您的吗?
# 0 没有了谢谢

# %%
import os

cluster_path = './cluster/'

if not os.path.exists(cluster_path):
    os.mkdir(cluster_path)

for i in range(n_clusters):
    file_name = cluster_path + 'cluster-%d.txt' % i
    with open(file_name, 'w', encoding='utf8') as f:
        for conv in clusters[i]:
            f.write(conv + '\n\n')
